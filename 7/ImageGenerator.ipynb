# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# # データの読み込み

# %%
(x_train, t_train), (x_test, t_test) = cifar10.load_data()
cifar10_labels = np.array(["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"])
image = x_train[12]
plt.imshow(image)
plt.show()

# %% [markdown]
# # ImageDataGenerator()

# %% [markdown]
# gen = ImageDataGenerator('拡張設定').flow(x, batch_size)
# '拡張設定'：この後詳しく説明
# x：(batch_size, width, height, channel)の4次元のデータを要求される。3次元画像データにbatch_sizeを付け足して4次元にする
# batch_size：まとめて処理する画像枚数
# genに拡張した画像のイテレータが返される

# %% [markdown]
# ## 画像拡張と表示の関数

# %%
def show_images(image, generator):
    # channel, height, width = image.shape
    # image = image.reshape(1, channel, height, width)
    height, width, channel = image.shape
    x = image.reshape(1, height, width, channel) # 4次元化
    gen = generator.flow(x, batch_size=1) # 画像拡張
    print(gen.next().shape)
    
    plt.figure(figsize=(9, 9))
    for i in range(9):
        gen_img = gen.next()[0].astype(np.uint8) # 4次元から3次元にして、画像化
        plt.subplot(3, 3, i+1)
        plt.imshow(gen_img)
    plt.show()

# %% [markdown]
# ## rotation_range
# 指定された角度の範囲でランダムに回転を行う

# %%
generator = ImageDataGenerator(rotation_range=20)
show_images(image, generator)
# Out:
# (1, 32, 32, 3)

# %% [markdown]
# ## width_shift_range
# 水平方向にシフトする

# %%
generator = ImageDataGenerator(width_shift_range=0.5)
show_images(image, generator)
# Out:
# (1, 32, 32, 3)

# %% [markdown]
# ## height_shift_range
# 垂直方向にシフトする

# %%
generator = ImageDataGenerator(height_shift_range=0.5)
show_images(image, generator)
# Out:
# (1, 32, 32, 3)

# %% [markdown]
# ## shear_range
# シアー変換を行う。
# 指定された角度内でランダムに画像を引っ張る。

# %%
generator = ImageDataGenerator(shear_range=20)
show_images(image, generator)
# Out:
# (1, 32, 32, 3)

# %% [markdown]
# ## zoom_range
# 指定された範囲内で水平、垂直方向を拡大する

# %%
generator = ImageDataGenerator(zoom_range=0.4)
show_images(image, generator)
# Out:
# (1, 32, 32, 3)

# %% [markdown]
# ## horizontal_flip, vertical_flip
# 水平、垂直方向に反転させる

# %%
generator = ImageDataGenerator(horizontal_flip=True, vertical_flip=True)
show_images(image, generator)
# Out:
# (1, 32, 32, 3)

# %% [markdown]
# # モデル構築

# %%
n_class = 10
t_train = tf.keras.utils.to_categorical(t_train, n_class)
t_test = tf.keras.utils.to_categorical(t_test, n_class)

model = Sequential()

model.add(Conv2D(32, (3, 3), padding='same', input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(n_class))
model.add(Activation('softmax'))

model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # 学習

# %% [markdown]
# gen = generator.flow(x, t, batch_size)
# x：batchsize+画像データ
# t：答えラベル
# batch_size：batch size
#
# gen：(x, t)のイテレータ
# x：生成された画像データ
# t：生成された画像データのラベル

# %%
gen = generator.flow(x_train, t_train, batch_size=32)
print(gen.next()[0].shape)
print(gen.next()[1].shape)
# Out:
# (32, 32, 32, 3)
# (32, 10)

# %%
x_train = x_train / 255
x_test = x_test / 255
epochs = 20
batch_size = 32

generator = ImageDataGenerator(rotation_range=0.2, horizontal_flip=True)
generator.fit(x_train)

# history = model.fit(x_train, t_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, t_test))
history = model.fit(generator.flow(x_train, t_train, batch_size=batch_size), epochs=epochs, validation_data=(x_test, t_test))
# Out:
# Epoch 1/20
# 1563/1563 [==============================] - 32s 20ms/step - loss: 1.5173 - accuracy: 0.4462 - val_loss: 1.1247 - val_accuracy: 0.5918
# Epoch 2/20
# 1563/1563 [==============================] - 26s 16ms/step - loss: 1.0940 - accuracy: 0.6163 - val_loss: 0.9426 - val_accuracy: 0.6705
# Epoch 3/20
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.9382 - accuracy: 0.6728 - val_loss: 0.8186 - val_accuracy: 0.7120
# Epoch 4/20
# 1563/1563 [==============================] - 29s 19ms/step - loss: 0.8390 - accuracy: 0.7082 - val_loss: 0.7616 - val_accuracy: 0.7372
# Epoch 5/20
# 1563/1563 [==============================] - 26s 16ms/step - loss: 0.7802 - accuracy: 0.7297 - val_loss: 0.7258 - val_accuracy: 0.7504
# Epoch 6/20
# 1563/1563 [==============================] - 26s 16ms/step - loss: 0.7301 - accuracy: 0.7478 - val_loss: 0.7042 - val_accuracy: 0.7526
# Epoch 7/20
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.6852 - accuracy: 0.7619 - val_loss: 0.6827 - val_accuracy: 0.7640
# Epoch 8/20
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.6540 - accuracy: 0.7740 - val_loss: 0.7184 - val_accuracy: 0.7506
# Epoch 9/20
# 1563/1563 [==============================] - 26s 16ms/step - loss: 0.6349 - accuracy: 0.7804 - val_loss: 0.6800 - val_accuracy: 0.7727
# Epoch 10/20
# 1563/1563 [==============================] - 27s 17ms/step - loss: 0.6011 - accuracy: 0.7894 - val_loss: 0.6796 - val_accuracy: 0.7695
# Epoch 11/20
# 1563/1563 [==============================] - 26s 16ms/step - loss: 0.5807 - accuracy: 0.7996 - val_loss: 0.6902 - val_accuracy: 0.7729
# Epoch 12/20
# 1563/1563 [==============================] - 26s 16ms/step - loss: 0.5643 - accuracy: 0.8013 - val_loss: 0.6606 - val_accuracy: 0.7777
# Epoch 13/20
# 1563/1563 [==============================] - 26s 16ms/step - loss: 0.5445 - accuracy: 0.8113 - val_loss: 0.6550 - val_accuracy: 0.7804
# Epoch 14/20
# 1563/1563 [==============================] - 26s 16ms/step - loss: 0.5196 - accuracy: 0.8201 - val_loss: 0.6684 - val_accuracy: 0.7758
# Epoch 15/20
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.5148 - accuracy: 0.8205 - val_loss: 0.6684 - val_accuracy: 0.7801
# Epoch 16/20
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.5036 - accuracy: 0.8256 - val_loss: 0.6612 - val_accuracy: 0.7844
# Epoch 17/20
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.4875 - accuracy: 0.8310 - val_loss: 0.6793 - val_accuracy: 0.7869
# Epoch 18/20
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.4749 - accuracy: 0.8321 - val_loss: 0.6546 - val_accuracy: 0.7879
# Epoch 19/20
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.4620 - accuracy: 0.8359 - val_loss: 0.6687 - val_accuracy: 0.7857
# Epoch 20/20
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.4449 - accuracy: 0.8432 - val_loss: 0.7401 - val_accuracy: 0.7792

# %% [markdown]
# # 学習結果

# %%
train_loss = history.history['loss']
test_loss = history.history['val_loss']
plt.title('loss')
plt.plot(np.arange(len(train_loss)), train_loss, label='train')
plt.plot(np.arange(len(test_loss)), test_loss, label='test')
plt.legend()
plt.show()

# %%
train_acc = history.history['accuracy']
test_acc = history.history['val_accuracy']
plt.title("accuracy")
plt.plot(np.arange(len(train_acc)), train_acc, label='train')
plt.plot(np.arange(len(test_acc)), test_acc, label='test')
plt.legend()
plt.show()

# %%
loss, accuracy = model.evaluate(x_test, t_test)
print("loss:", loss, "accuracy:", accuracy)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.7401 - accuracy: 0.7792
# loss: 0.7401453256607056 accuracy: 0.77920001745224

# %% [markdown]
# # モデルの保存

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# googleDriveと連携していいかの聞かれるので許可する

# %%
import os
path = '/content/drive/MyDrive/cnn_cifar/'

if not os.path.exists(path):
  os.makedirs(path)

model.save(path + "model_cnn_cifar10.h5")

# %%
from keras.models import load_model

path = '/content/drive/MyDrive/cnn_cifar/model_cnn_cifar10.h5'

new_model = load_model(path)

new_model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_16 (Conv2D)          (None, 32, 32, 32)        896
#
#  activation_24 (Activation)  (None, 32, 32, 32)        0
#
#  conv2d_17 (Conv2D)          (None, 30, 30, 32)        9248
#
#  activation_25 (Activation)  (None, 30, 30, 32)        0
#
#  max_pooling2d_8 (MaxPooling  (None, 15, 15, 32)       0
#  2D)
#
#  conv2d_18 (Conv2D)          (None, 15, 15, 64)        18496
#
#  activation_26 (Activation)  (None, 15, 15, 64)        0
#
#  conv2d_19 (Conv2D)          (None, 13, 13, 64)        36928
#
#  activation_27 (Activation)  (None, 13, 13, 64)        0
#
#  max_pooling2d_9 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  flatten_4 (Flatten)         (None, 2304)              0
#
#  dense_8 (Dense)             (None, 256)               590080
#
#  activation_28 (Activation)  (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_9 (Dense)             (None, 10)                2570
#
#  activation_29 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 658,218
# Trainable params: 658,218
# Non-trainable params: 0
# _________________________________________________________________
